# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../data/homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # Looking at the data if the data is sutiable for a linear regresssion line

# %%
# %matplotlib inline
plt.scatter(df.area , df.price, color = 'red' , marker='+')
plt.xlabel('Sqrt (size)')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
X = df['area']

# %%
X[0]
# Out:
# 2600

# %%
y = df['price']

# %%
w = 0.5
b = 50

# %%
def hypothesis(x):
    return w * x + b

# %%
def cost_func (X , y):
    m = len (y)
    prediction = hypothesis (X)
    return (1 / (2*m))* np.sum(((prediction - y) **2))

# %%
def GD (X, y , w, b, lr, epoch):
    m = len (y)
    cost_history= []
    for _ in range(epoch):
        predictions = hypothesis(X)
        dw = (1 / m) * np.sum((predictions - y) * X)
        db = (1 / m) * np.sum(predictions - y)
        w -= lr * dw
        b -= lr * db
        cost = cost_func(X, y)
        cost_history.append (cost)
        
    return w, b, cost_history

# %%
lr = 0.001
epoch = 1000
w, b, cost_history = GD (X, y, w, b, lr, epoch)

# %%
new_house = 2600
new_house_price = hypothesis(new_house)
print (f"the house with the size {new_house} price is $:{new_house_price:.2f}")
# Out:
# the house with the size 2600 price is $:5406284625660.00

# %%
plt.scatter(X, y, color='red', marker='+', label='Actual Data')
plt.xlabel('Size')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.plot(X, hypothesis(X), color='blue', label='Regression Line')

# %%
plt.scatter(new_house, new_house_price, color='green', marker='o', label=f'Predicted Price: ${new_house_price:.2f}')
plt.legend()
plt.show()

# %%
plt.scatter(X, y, color='red', marker='+', label='Actual Data')
plt.plot(X, hypothesis(X), color='blue', label='Regression Line')
plt.xlabel('Size')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.scatter(X, y, color='red', marker='+', label='Actual Data')
plt.plot(X, hypothesis(X), color='blue', label='Regression Line')
plt.xlabel('Size')
plt.ylabel('Price')
plt.legend()
plt.show()
